# %%
import numpy as np
import tensorflow as tf
import math
import os
import utils as utils

# %%
np.random.seed(0)
tf.set_random_seed(0)

data_dir = 'data/20news/'
learning_rate = 5e-5
batch_size = 64
n_hidden = 500
n_topic = 50
vocab_size = 2000
non_linearity = tf.nn.tanh

# %%
def record(epoch = 0):
    f_vocab = os.path.join(data_dir, 'vocab.new')

    f = open(f_vocab)
    temp = f.readlines()
    f.close()

    voca = [word.strip().split(' ')[0] for word in temp]

    R = sess.run(nvdm.W_dec)

    for top_ind in range(n_topic):
        as_ = np.argsort(R[top_ind])
        t = [voca[ind] for ind in as_[-10:]]
        t.reverse()
        s = 'Topic %2d : '%(top_ind + 1)
        for word in t:
            s += ' %s,' % (word)

        print(s[:-1])

# %%
A = [1, 2, 3, 87]
B = [4, 5, 6, 7]

for a, b in zip(A, B):
    print(a, b)
# Out:
# 1 4
# 2 5
# 3 6
# 87 7

# %%
class NVDM(object):
    """ Neural Variational Document nvdm -- BOW VAE.
    """
    def __init__(self, vocab_size, n_hidden, n_topic, learning_rate, batch_size, non_linearity):
        self.vocab_size = vocab_size
        self.n_hidden = n_hidden
        self.n_topic = n_topic
        self.non_linearity = non_linearity
        self.learning_rate = learning_rate
        self.batch_size = batch_size

        self.x = tf.placeholder(tf.float32, [None, vocab_size], name='input')
        self.mask = tf.placeholder(tf.float32, [None], name='mask')  # mask paddings
        
        # encoder
        with tf.variable_scope('encoder'): 
            self.W_enc = tf.get_variable('enc_W', [self.vocab_size, n_hidden], initializer = None)
            self.b_enc = tf.get_variable('enc_b', [n_hidden], initializer = None)            
            self.enc_vec = self.non_linearity(tf.matmul(self.x, self.W_enc) + self.b_enc)
            
            self.W_mean = tf.get_variable('mean_W', [self.n_hidden, self.n_topic], initializer = None)
            self.b_mean = tf.get_variable('mean_b', [self.n_topic], initializer = None)            
            self.mean = tf.matmul(self.enc_vec, self.W_mean) + self.b_mean
            
            self.W_logsigm = tf.get_variable('logsigm_W', [self.n_hidden, self.n_topic], initializer = tf.constant_initializer(0))
            self.b_logsigm = tf.get_variable('logsigm_b', [self.n_topic], initializer = tf.constant_initializer(0))            
            self.logsigm = tf.matmul(self.enc_vec, self.W_logsigm) + self.b_logsigm
            
            self.kld = -0.5 * tf.reduce_sum(1 - tf.square(self.mean) + 2 * self.logsigm - tf.exp(2 * self.logsigm), 1)
            self.kld = self.mask * self.kld  # mask paddings
        
        with tf.variable_scope('decoder'):
            eps = tf.random_normal((batch_size, self.n_topic), 0, 1)
            doc_vec = tf.multiply(tf.exp(self.logsigm), eps) + self.mean #reparametrization tech.
            
            self.W_dec = tf.get_variable('dec_W', [self.n_topic, self.vocab_size], initializer = None)
#             self.b_dec = tf.get_variable('dec_b', [self.vocab_size], initializer = None)            
            self.logits = tf.nn.log_softmax(tf.matmul(doc_vec, self.W_dec))
            
            self.recons_loss = - tf.reduce_sum(tf.multiply(self.logits, self.x), 1)

        self.objective = self.recons_loss + self.kld

        optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate)
        fullvars = tf.trainable_variables()

        enc_vars = utils.variable_parser(fullvars, 'encoder')
        dec_vars = utils.variable_parser(fullvars, 'decoder')

        enc_grads = tf.gradients(self.objective, enc_vars)
        dec_grads = tf.gradients(self.objective, dec_vars)

        self.optim_enc = optimizer.apply_gradients(zip(enc_grads, enc_vars))
        self.optim_dec = optimizer.apply_gradients(zip(dec_grads, dec_vars))

# %%
train_url = os.path.join(data_dir, 'train.feat')
test_url = os.path.join(data_dir, 'test.feat')

train_set, train_count = utils.data_set(train_url)
test_set, test_count = utils.data_set(test_url)

test_batches = utils.create_batches(len(test_set), batch_size, shuffle=False)

# %%
nvdm = NVDM(vocab_size=vocab_size,
            n_hidden=n_hidden,
            n_topic=n_topic, 
            learning_rate=learning_rate, 
            batch_size=batch_size,
            non_linearity=non_linearity)

sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

training_epochs = 1000
alternate_epochs = 10

# %%
for epoch in range(training_epochs):
    
    train_batches = utils.create_batches(len(train_set), batch_size, shuffle=True)
    #-------------------------------
    # train
    for switch in range(2):
        if switch == 0:
            optim = nvdm.optim_dec
            print_mode = 'decoder'
            
        else:
            optim = nvdm.optim_enc
            print_mode = 'encoder'

        for i in range(alternate_epochs):
            loss_sum = 0.0
            ppx_sum = 0.0
            kld_sum = 0.0
            word_count = 0
            doc_count = 0
            for idx_batch in train_batches: # train_batches : 전체 N, idx_batch : 64개씩 있는 집합.
                data_batch, count_batch, mask = utils.fetch_data(
                train_set, train_count, idx_batch, vocab_size)
                input_feed = {nvdm.x.name: data_batch, nvdm.mask.name: mask}
                _, (loss, kld) = sess.run((optim, [nvdm.objective, nvdm.kld]), input_feed)
                loss_sum += np.sum(loss)
                kld_sum += np.sum(kld) / np.sum(mask) 
                word_count += np.sum(count_batch)
                # to avoid nan error
                count_batch = np.add(count_batch, 1e-12)
                # per document loss
                ppx_sum += np.sum(np.divide(loss, count_batch)) 
                doc_count += np.sum(mask)
            print_ppx = np.exp(loss_sum / word_count)
            print_ppx_perdoc = np.exp(ppx_sum / doc_count)
            print_kld = kld_sum/len(train_batches)
        print('Epoch train : %3d | Perplexity : %10.5f | Per doc ppx : %10.5f | KLD : %10.5f'
              %(epoch + 1, print_ppx, print_ppx_perdoc, print_kld))

    #-------------------------------
    # test
    loss_sum = 0.0
    kld_sum = 0.0
    ppx_sum = 0.0
    word_count = 0
    doc_count = 0
    for idx_batch in test_batches:
        data_batch, count_batch, mask = utils.fetch_data(test_set, test_count, idx_batch, vocab_size)
        input_feed = {nvdm.x.name: data_batch, nvdm.mask.name: mask}
        loss, kld = sess.run([nvdm.objective, nvdm.kld], input_feed)
        loss_sum += np.sum(loss)
        kld_sum += np.sum(kld)/np.sum(mask) 
        word_count += np.sum(count_batch)
        count_batch = np.add(count_batch, 1e-12)
        ppx_sum += np.sum(np.divide(loss, count_batch))
        doc_count += np.sum(mask) 
    print_ppx = np.exp(loss_sum / word_count)
    print_ppx_perdoc = np.exp(ppx_sum / doc_count)
    print_kld = kld_sum/len(test_batches)
    print('Epoch test  : %3d | Perplexity : %10.5f | Per doc ppx : %10.5f | KLD : %10.5f'
          %(epoch + 1, print_ppx, print_ppx_perdoc, print_kld))
    print('')
# Out:
# Epoch train :   1 | Perplexity :  951.93697 | Per doc ppx : 1228.36851 | KLD :   18.25757
# Epoch train :   1 | Perplexity :  943.20369 | Per doc ppx : 1223.29072 | KLD :   19.17136
# Epoch test  :   1 | Perplexity : 1021.50917 | Per doc ppx : 1241.21377 | KLD :   17.16118
#
# Epoch train :   2 | Perplexity :  909.58945 | Per doc ppx : 1180.28747 | KLD :   19.18850
# Epoch train :   2 | Perplexity :  903.99683 | Per doc ppx : 1174.74989 | KLD :   19.81148
# Epoch test  :   2 | Perplexity :  990.32191 | Per doc ppx : 1203.46759 | KLD :   17.69938
#
# Epoch train :   3 | Perplexity :  876.05640 | Per doc ppx : 1140.34456 | KLD :   19.84391
# Epoch train :   3 | Perplexity :  870.99740 | Per doc ppx : 1133.42457 | KLD :   20.30892
# Epoch test  :   3 | Perplexity :  964.05298 | Per doc ppx : 1163.50348 | KLD :   17.93583
#
# Epoch train :   4 | Perplexity :  849.45201 | Per doc ppx : 1102.90146 | KLD :   20.28076
# Epoch train :   4 | Perplexity :  844.67123 | Per doc ppx : 1100.06844 | KLD :   20.85953
# Epoch test  :   4 | Perplexity :  943.48509 | Per doc ppx : 1137.19442 | KLD :   18.40232
#
# Epoch train :   5 | Perplexity :  827.12961 | Per doc ppx : 1076.95227 | KLD :   20.77646
# Epoch train :   5 | Perplexity :  822.80598 | Per doc ppx : 1071.47024 | KLD :   21.23490
# Epoch test  :   5 | Perplexity :  924.48654 | Per doc ppx : 1110.68656 | KLD :   18.82872
#
# Epoch train :   6 | Perplexity :  807.34065 | Per doc ppx : 1048.89950 | KLD :   21.23470
# Epoch train :   6 | Perplexity :  804.44899 | Per doc ppx : 1047.33980 | KLD :   21.71734
# Epoch test  :   6 | Perplexity :  909.72845 | Per doc ppx : 1090.89407 | KLD :   19.20049
#
# Epoch train :   7 | Perplexity :  790.92451 | Per doc ppx : 1028.49701 | KLD :   21.68604
# Epoch train :   7 | Perplexity :  787.61795 | Per doc ppx : 1022.38912 | KLD :   22.17358
# Epoch test  :   7 | Perplexity :  896.71759 | Per doc ppx : 1070.31738 | KLD :   19.63581
#
# Epoch train :   8 | Perplexity :  776.88096 | Per doc ppx : 1008.24119 | KLD :   22.21815
# Epoch train :   8 | Perplexity :  773.97645 | Per doc ppx : 1003.62189 | KLD :   22.55399
# Epoch test  :   8 | Perplexity :  888.49812 | Per doc ppx : 1057.62142 | KLD :   19.89407
#
# Epoch train :   9 | Perplexity :  763.50316 | Per doc ppx :  989.05451 | KLD :   22.61111
# Epoch train :   9 | Perplexity :  761.95435 | Per doc ppx :  987.25366 | KLD :   23.05182
# Epoch test  :   9 | Perplexity :  881.52535 | Per doc ppx : 1045.43623 | KLD :   20.28268
#
# Epoch train :  10 | Perplexity :  752.76087 | Per doc ppx :  973.02682 | KLD :   23.07319
# Epoch train :  10 | Perplexity :  751.25673 | Per doc ppx :  971.63710 | KLD :   23.40698
# Epoch test  :  10 | Perplexity :  873.39539 | Per doc ppx : 1033.65780 | KLD :   20.55707
#
# Epoch train :  11 | Perplexity :  743.58832 | Per doc ppx :  959.71645 | KLD :   23.24833
# Epoch train :  11 | Perplexity :  741.22291 | Per doc ppx :  955.97189 | KLD :   23.62733
# Epoch test  :  11 | Perplexity :  865.60036 | Per doc ppx : 1021.22518 | KLD :   20.86921
#
# Epoch train :  12 | Perplexity :  733.43378 | Per doc ppx :  943.60687 | KLD :   23.66525
# Epoch train :  12 | Perplexity :  732.88320 | Per doc ppx :  944.12893 | KLD :   23.96314
# Epoch test  :  12 | Perplexity :  859.07585 | Per doc ppx : 1013.55528 | KLD :   21.17165
#
# Epoch train :  13 | Perplexity :  726.15587 | Per doc ppx :  935.33869 | KLD :   23.91738
# Epoch train :  13 | Perplexity :  725.32610 | Per doc ppx :  932.25571 | KLD :   24.18736
# Epoch test  :  13 | Perplexity :  856.93554 | Per doc ppx : 1005.53174 | KLD :   21.39155
#
# Epoch train :  14 | Perplexity :  718.41186 | Per doc ppx :  923.43908 | KLD :   24.14751
# Epoch train :  14 | Perplexity :  717.64063 | Per doc ppx :  921.41329 | KLD :   24.39159
# Epoch test  :  14 | Perplexity :  852.80165 | Per doc ppx :  997.08549 | KLD :   21.75472
#
# Epoch train :  15 | Perplexity :  712.98233 | Per doc ppx :  913.97306 | KLD :   24.49811
# Epoch train :  15 | Perplexity :  712.35371 | Per doc ppx :  912.77724 | KLD :   24.77722
# Epoch test  :  15 | Perplexity :  848.61486 | Per doc ppx :  989.57536 | KLD :   21.85570
#
# Epoch train :  16 | Perplexity :  707.30220 | Per doc ppx :  902.89611 | KLD :   24.73040
# Epoch train :  16 | Perplexity :  705.80139 | Per doc ppx :  902.54044 | KLD :   25.03656
# Epoch test  :  16 | Perplexity :  846.03685 | Per doc ppx :  985.04710 | KLD :   22.22287
#
# Epoch train :  17 | Perplexity :  701.64802 | Per doc ppx :  895.76915 | KLD :   25.10958
# Epoch train :  17 | Perplexity :  700.53037 | Per doc ppx :  893.46514 | KLD :   25.22708
# Epoch test  :  17 | Perplexity :  839.99059 | Per doc ppx :  978.52623 | KLD :   22.51928
#
# Epoch train :  18 | Perplexity :  697.31669 | Per doc ppx :  890.18694 | KLD :   25.34351
# Epoch train :  18 | Perplexity :  695.90626 | Per doc ppx :  886.39695 | KLD :   25.44710
# Epoch test  :  18 | Perplexity :  838.04308 | Per doc ppx :  974.71100 | KLD :   22.78494
#
# Epoch train :  19 | Perplexity :  692.52675 | Per doc ppx :  881.79922 | KLD :   25.67313
# Epoch train :  19 | Perplexity :  691.89075 | Per doc ppx :  881.53732 | KLD :   25.71555
# Epoch test  :  19 | Perplexity :  836.04141 | Per doc ppx :  972.63012 | KLD :   22.87813
#
# Epoch train :  20 | Perplexity :  688.96706 | Per doc ppx :  876.28371 | KLD :   25.70552
# Epoch train :  20 | Perplexity :  688.64878 | Per doc ppx :  877.69051 | KLD :   25.91139
# Epoch test  :  20 | Perplexity :  834.87234 | Per doc ppx :  967.19052 | KLD :   23.06967
#
# Epoch train :  21 | Perplexity :  685.25584 | Per doc ppx :  870.32965 | KLD :   26.03189
# Epoch train :  21 | Perplexity :  684.71503 | Per doc ppx :  871.04536 | KLD :   26.16542
# Epoch test  :  21 | Perplexity :  832.60205 | Per doc ppx :  963.78874 | KLD :   23.28932
#
# Epoch train :  22 | Perplexity :  680.87162 | Per doc ppx :  862.91114 | KLD :   26.08163
# Epoch train :  22 | Perplexity :  680.76158 | Per doc ppx :  863.59806 | KLD :   26.20298
# Epoch test  :  22 | Perplexity :  831.97028 | Per doc ppx :  962.60171 | KLD :   23.61753
#
# Epoch train :  23 | Perplexity :  678.69583 | Per doc ppx :  860.72711 | KLD :   26.45065
# Epoch train :  23 | Perplexity :  678.16246 | Per doc ppx :  859.16867 | KLD :   26.39648
# Epoch test  :  23 | Perplexity :  832.13767 | Per doc ppx :  959.06440 | KLD :   23.64200
#
# Epoch train :  24 | Perplexity :  675.00854 | Per doc ppx :  853.01880 | KLD :   26.45002
# Epoch train :  24 | Perplexity :  675.75452 | Per doc ppx :  855.30761 | KLD :   26.59019
# Epoch test  :  24 | Perplexity :  830.33422 | Per doc ppx :  952.71118 | KLD :   23.97335
#
# Epoch train :  25 | Perplexity :  672.88273 | Per doc ppx :  849.84396 | KLD :   26.76261
# Epoch train :  25 | Perplexity :  671.73232 | Per doc ppx :  848.10659 | KLD :   26.60928
# Epoch test  :  25 | Perplexity :  829.53006 | Per doc ppx :  956.37587 | KLD :   23.71582
#
# Epoch train :  26 | Perplexity :  670.65988 | Per doc ppx :  847.12828 | KLD :   26.55813
# Epoch train :  26 | Perplexity :  669.90609 | Per doc ppx :  845.48540 | KLD :   26.85576
# Epoch test  :  26 | Perplexity :  827.67229 | Per doc ppx :  951.27768 | KLD :   24.11673
#
# Epoch train :  27 | Perplexity :  667.83466 | Per doc ppx :  841.32680 | KLD :   26.97980
# Epoch train :  27 | Perplexity :  667.32389 | Per doc ppx :  843.20826 | KLD :   26.99486
# Epoch test  :  27 | Perplexity :  827.09249 | Per doc ppx :  947.22722 | KLD :   23.80063
#
# Epoch train :  28 | Perplexity :  665.43159 | Per doc ppx :  837.61139 | KLD :   26.58649
# Epoch train :  28 | Perplexity :  664.91276 | Per doc ppx :  836.13839 | KLD :   27.00230
# Epoch test  :  28 | Perplexity :  826.21224 | Per doc ppx :  946.29748 | KLD :   24.13670
#
# Epoch train :  29 | Perplexity :  663.67525 | Per doc ppx :  834.58796 | KLD :   26.98463
# Epoch train :  29 | Perplexity :  663.68972 | Per doc ppx :  836.53667 | KLD :   27.18275
# Epoch test  :  29 | Perplexity :  824.39901 | Per doc ppx :  941.32128 | KLD :   24.56189
#
# Epoch train :  30 | Perplexity :  661.91178 | Per doc ppx :  832.24703 | KLD :   27.49855
# Epoch train :  30 | Perplexity :  661.56743 | Per doc ppx :  831.64896 | KLD :   27.46467
# Epoch test  :  30 | Perplexity :  824.89327 | Per doc ppx :  943.92524 | KLD :   24.62346
#
# Epoch train :  31 | Perplexity :  659.47677 | Per doc ppx :  827.17280 | KLD :   27.43506
# Epoch train :  31 | Perplexity :  659.74570 | Per doc ppx :  826.73506 | KLD :   27.50906
# Epoch test  :  31 | Perplexity :  822.78834 | Per doc ppx :  941.34096 | KLD :   24.69389
#
# Epoch train :  32 | Perplexity :  658.32210 | Per doc ppx :  827.57906 | KLD :   27.51180
# Epoch train :  32 | Perplexity :  658.78377 | Per doc ppx :  827.48544 | KLD :   27.64619
# Epoch test  :  32 | Perplexity :  823.80386 | Per doc ppx :  941.96694 | KLD :   24.57875
#
# Epoch train :  33 | Perplexity :  656.85516 | Per doc ppx :  824.82932 | KLD :   27.53695
# Epoch train :  33 | Perplexity :  656.07370 | Per doc ppx :  821.81172 | KLD :   27.76069
# Epoch test  :  33 | Perplexity :  824.93944 | Per doc ppx :  938.66103 | KLD :   24.77924
#
# Epoch train :  34 | Perplexity :  655.48423 | Per doc ppx :  821.09795 | KLD :   27.61959
# Epoch train :  34 | Perplexity :  655.08978 | Per doc ppx :  819.89180 | KLD :   27.82309
# Epoch test  :  34 | Perplexity :  822.83043 | Per doc ppx :  940.26618 | KLD :   24.88937
#
# Epoch train :  35 | Perplexity :  653.74680 | Per doc ppx :  817.10656 | KLD :   27.73772
# Epoch train :  35 | Perplexity :  653.39070 | Per doc ppx :  815.80399 | KLD :   27.89859
# Epoch test  :  35 | Perplexity :  820.50868 | Per doc ppx :  936.02286 | KLD :   25.22069
#
# Epoch train :  36 | Perplexity :  652.99972 | Per doc ppx :  816.98336 | KLD :   28.00561
# Epoch train :  36 | Perplexity :  652.44631 | Per doc ppx :  815.49947 | KLD :   27.95424
# Epoch test  :  36 | Perplexity :  823.94357 | Per doc ppx :  938.94521 | KLD :   25.26580
#
# Epoch train :  37 | Perplexity :  651.22590 | Per doc ppx :  813.04788 | KLD :   28.05985
# Epoch train :  37 | Perplexity :  650.81465 | Per doc ppx :  813.69831 | KLD :   28.01480
# Epoch test  :  37 | Perplexity :  823.10126 | Per doc ppx :  936.24652 | KLD :   25.63336
#
# Epoch train :  38 | Perplexity :  650.15509 | Per doc ppx :  811.41943 | KLD :   28.40662
# Epoch train :  38 | Perplexity :  650.31275 | Per doc ppx :  812.12091 | KLD :   28.22244
# Epoch test  :  38 | Perplexity :  822.71625 | Per doc ppx :  935.63448 | KLD :   25.50674
#
# Epoch train :  39 | Perplexity :  648.31314 | Per doc ppx :  809.80328 | KLD :   28.31869
# Epoch train :  39 | Perplexity :  648.79778 | Per doc ppx :  809.74965 | KLD :   28.33458
# Epoch test  :  39 | Perplexity :  822.72536 | Per doc ppx :  934.89406 | KLD :   25.58851
#
# Epoch train :  40 | Perplexity :  647.82582 | Per doc ppx :  807.54207 | KLD :   28.44671
# Epoch train :  40 | Perplexity :  647.28591 | Per doc ppx :  806.96449 | KLD :   28.40108
# Epoch test  :  40 | Perplexity :  823.99402 | Per doc ppx :  937.32428 | KLD :   25.83963
#
# Epoch train :  41 | Perplexity :  646.52394 | Per doc ppx :  802.72621 | KLD :   28.57377
# Epoch train :  41 | Perplexity :  646.60520 | Per doc ppx :  805.17806 | KLD :   28.42618
# Epoch test  :  41 | Perplexity :  821.80647 | Per doc ppx :  933.15927 | KLD :   25.89714
#
# Epoch train :  42 | Perplexity :  645.76294 | Per doc ppx :  802.50447 | KLD :   28.65004
# Epoch train :  42 | Perplexity :  645.43264 | Per doc ppx :  804.49307 | KLD :   28.52248
# Epoch test  :  42 | Perplexity :  823.06632 | Per doc ppx :  933.52495 | KLD :   25.67643
#
# Epoch train :  43 | Perplexity :  645.36590 | Per doc ppx :  804.45252 | KLD :   28.44223
# Epoch train :  43 | Perplexity :  644.67762 | Per doc ppx :  800.60583 | KLD :   28.66599
# Epoch test  :  43 | Perplexity :  821.89876 | Per doc ppx :  934.44020 | KLD :   25.98409
#
# Epoch train :  44 | Perplexity :  643.51447 | Per doc ppx :  800.48852 | KLD :   28.78455
# Epoch train :  44 | Perplexity :  643.85850 | Per doc ppx :  799.53818 | KLD :   28.78775
# Epoch test  :  44 | Perplexity :  823.20448 | Per doc ppx :  932.21352 | KLD :   25.86196
#
# Epoch train :  45 | Perplexity :  642.23108 | Per doc ppx :  796.38867 | KLD :   28.57465
# Epoch train :  45 | Perplexity :  642.98239 | Per doc ppx :  797.12326 | KLD :   28.75105
# Epoch test  :  45 | Perplexity :  823.17572 | Per doc ppx :  933.97187 | KLD :   25.83034
#
# Epoch train :  46 | Perplexity :  642.34370 | Per doc ppx :  796.53178 | KLD :   28.58240
# Epoch train :  46 | Perplexity :  642.59103 | Per doc ppx :  797.61975 | KLD :   28.90438
# Epoch test  :  46 | Perplexity :  824.73292 | Per doc ppx :  931.98253 | KLD :   26.33582
#
# Epoch train :  47 | Perplexity :  642.18169 | Per doc ppx :  798.16821 | KLD :   29.02747
# Epoch train :  47 | Perplexity :  641.56399 | Per doc ppx :  796.32186 | KLD :   28.88215
# Epoch test  :  47 | Perplexity :  823.39503 | Per doc ppx :  934.08595 | KLD :   26.13863
#
# Epoch train :  48 | Perplexity :  640.26654 | Per doc ppx :  793.49480 | KLD :   28.79341
# Epoch train :  48 | Perplexity :  640.85862 | Per doc ppx :  793.60346 | KLD :   28.92330
# Epoch test  :  48 | Perplexity :  823.13654 | Per doc ppx :  931.69375 | KLD :   26.32083
#
# Epoch train :  49 | Perplexity :  640.09436 | Per doc ppx :  793.08663 | KLD :   29.10596
# Epoch train :  49 | Perplexity :  640.57055 | Per doc ppx :  794.43799 | KLD :   29.11442
# Epoch test  :  49 | Perplexity :  824.99736 | Per doc ppx :  931.16206 | KLD :   26.35377
#
# Epoch train :  50 | Perplexity :  638.79499 | Per doc ppx :  788.85032 | KLD :   29.10066
# Epoch train :  50 | Perplexity :  638.90086 | Per doc ppx :  789.27257 | KLD :   29.12542
# Epoch test  :  50 | Perplexity :  824.41015 | Per doc ppx :  933.98945 | KLD :   26.46215
#
# Epoch train :  51 | Perplexity :  638.72551 | Per doc ppx :  792.58355 | KLD :   29.16051
# Epoch train :  51 | Perplexity :  638.42980 | Per doc ppx :  788.30400 | KLD :   29.16861
# Epoch test  :  51 | Perplexity :  823.11487 | Per doc ppx :  932.02294 | KLD :   26.57008
#
# Epoch train :  52 | Perplexity :  637.90959 | Per doc ppx :  787.46054 | KLD :   29.26125
# Epoch train :  52 | Perplexity :  638.67887 | Per doc ppx :  788.89039 | KLD :   29.31321
# Epoch test  :  52 | Perplexity :  824.37933 | Per doc ppx :  930.15005 | KLD :   26.72939
#
# Epoch train :  53 | Perplexity :  637.96883 | Per doc ppx :  789.13942 | KLD :   29.48064
# Epoch train :  53 | Perplexity :  637.06164 | Per doc ppx :  787.15795 | KLD :   29.35120
# Epoch test  :  53 | Perplexity :  823.96346 | Per doc ppx :  928.33041 | KLD :   26.38292
#
# Epoch train :  54 | Perplexity :  636.18440 | Per doc ppx :  786.90648 | KLD :   29.05233
# Epoch train :  54 | Perplexity :  636.44594 | Per doc ppx :  787.39713 | KLD :   29.27768
# Epoch test  :  54 | Perplexity :  824.62247 | Per doc ppx :  929.47983 | KLD :   26.58471
#
# Epoch train :  55 | Perplexity :  635.47587 | Per doc ppx :  781.75651 | KLD :   29.31352
# Epoch train :  55 | Perplexity :  635.84086 | Per doc ppx :  783.20553 | KLD :   29.41492
# Epoch test  :  55 | Perplexity :  823.89388 | Per doc ppx :  927.58657 | KLD :   26.88848
#
# Epoch train :  56 | Perplexity :  635.18274 | Per doc ppx :  783.92990 | KLD :   29.55450
# Epoch train :  56 | Perplexity :  635.22836 | Per doc ppx :  783.65884 | KLD :   29.41795
# Epoch test  :  56 | Perplexity :  824.08876 | Per doc ppx :  929.78224 | KLD :   26.78041
#
# Epoch train :  57 | Perplexity :  634.90187 | Per doc ppx :  784.79303 | KLD :   29.46050
# Epoch train :  57 | Perplexity :  634.42151 | Per doc ppx :  781.63986 | KLD :   29.47263
# Epoch test  :  57 | Perplexity :  825.67835 | Per doc ppx :  930.58720 | KLD :   26.69439
#
# Epoch train :  58 | Perplexity :  634.45615 | Per doc ppx :  783.99280 | KLD :   29.31860
# Epoch train :  58 | Perplexity :  634.39254 | Per doc ppx :  783.32308 | KLD :   29.45461
# Epoch test  :  58 | Perplexity :  824.30948 | Per doc ppx :  929.53141 | KLD :   26.70456
#
# Epoch train :  59 | Perplexity :  634.80496 | Per doc ppx :  782.55100 | KLD :   29.38103
# Epoch train :  59 | Perplexity :  633.79475 | Per doc ppx :  780.19488 | KLD :   29.54447
# Epoch test  :  59 | Perplexity :  825.06873 | Per doc ppx :  927.71957 | KLD :   26.75736
#
# Epoch train :  60 | Perplexity :  633.47936 | Per doc ppx :  778.80214 | KLD :   29.42588
# Epoch train :  60 | Perplexity :  633.37648 | Per doc ppx :  778.79709 | KLD :   29.58130
# Epoch test  :  60 | Perplexity :  823.96531 | Per doc ppx :  929.76400 | KLD :   26.80011
#
# Epoch train :  61 | Perplexity :  632.80030 | Per doc ppx :  777.45924 | KLD :   29.53464
# Epoch train :  61 | Perplexity :  632.97202 | Per doc ppx :  778.54086 | KLD :   29.75191
# Epoch test  :  61 | Perplexity :  825.60351 | Per doc ppx :  926.03225 | KLD :   26.89282
#
# Epoch train :  62 | Perplexity :  632.89913 | Per doc ppx :  778.17938 | KLD :   29.56360
# Epoch train :  62 | Perplexity :  632.48591 | Per doc ppx :  776.63788 | KLD :   29.68353
# Epoch test  :  62 | Perplexity :  826.57570 | Per doc ppx :  930.64325 | KLD :   26.92283
#
# Epoch train :  63 | Perplexity :  632.06774 | Per doc ppx :  779.13879 | KLD :   29.71921
# Epoch train :  63 | Perplexity :  631.77807 | Per doc ppx :  776.53638 | KLD :   29.85500
# Epoch test  :  63 | Perplexity :  826.11563 | Per doc ppx :  928.34018 | KLD :   27.21500
#
# Epoch train :  64 | Perplexity :  631.41297 | Per doc ppx :  775.62118 | KLD :   29.87297
# Epoch train :  64 | Perplexity :  632.25826 | Per doc ppx :  777.31696 | KLD :   29.83401
# Epoch test  :  64 | Perplexity :  825.54375 | Per doc ppx :  928.08180 | KLD :   27.17603
#
# Epoch train :  65 | Perplexity :  631.39852 | Per doc ppx :  776.41624 | KLD :   29.83635
# Epoch train :  65 | Perplexity :  631.90806 | Per doc ppx :  777.09951 | KLD :   29.94956
# Epoch test  :  65 | Perplexity :  826.32588 | Per doc ppx :  930.02367 | KLD :   27.29264
#
# Epoch train :  66 | Perplexity :  630.44369 | Per doc ppx :  775.70247 | KLD :   29.93112
# Epoch train :  66 | Perplexity :  631.36002 | Per doc ppx :  776.26240 | KLD :   29.92710
# Epoch test  :  66 | Perplexity :  825.20962 | Per doc ppx :  929.81498 | KLD :   27.39293
#
# Epoch train :  67 | Perplexity :  630.95088 | Per doc ppx :  776.38570 | KLD :   30.03670
# Epoch train :  67 | Perplexity :  630.97480 | Per doc ppx :  776.94144 | KLD :   30.00093
# Epoch test  :  67 | Perplexity :  825.83349 | Per doc ppx :  925.87421 | KLD :   27.55595
#
# Epoch train :  68 | Perplexity :  630.03110 | Per doc ppx :  774.14782 | KLD :   30.21744
# Epoch train :  68 | Perplexity :  630.69187 | Per doc ppx :  774.99275 | KLD :   30.12579
# Epoch test  :  68 | Perplexity :  827.05123 | Per doc ppx :  927.10491 | KLD :   27.43082
#
# Epoch train :  69 | Perplexity :  629.76927 | Per doc ppx :  773.92279 | KLD :   30.04092
# Epoch train :  69 | Perplexity :  629.13522 | Per doc ppx :  772.00664 | KLD :   30.01654
# Epoch test  :  69 | Perplexity :  826.67147 | Per doc ppx :  926.26746 | KLD :   27.29837
#
# Epoch train :  70 | Perplexity :  629.56823 | Per doc ppx :  772.25048 | KLD :   29.96896
# Epoch train :  70 | Perplexity :  629.15058 | Per doc ppx :  771.84396 | KLD :   30.06734
# Epoch test  :  70 | Perplexity :  827.87301 | Per doc ppx :  928.96279 | KLD :   27.24477
#
# Epoch train :  71 | Perplexity :  629.41207 | Per doc ppx :  773.14461 | KLD :   30.02779
# Epoch train :  71 | Perplexity :  628.50900 | Per doc ppx :  769.86454 | KLD :   30.23368
# Epoch test  :  71 | Perplexity :  827.27915 | Per doc ppx :  926.72373 | KLD :   27.61420
#
# Epoch train :  72 | Perplexity :  628.57126 | Per doc ppx :  769.45181 | KLD :   30.30280
# Epoch train :  72 | Perplexity :  628.16059 | Per doc ppx :  769.61324 | KLD :   30.22117
# Epoch test  :  72 | Perplexity :  826.49581 | Per doc ppx :  924.87587 | KLD :   27.45352
#
# Epoch train :  73 | Perplexity :  628.23803 | Per doc ppx :  768.87723 | KLD :   30.03586
# Epoch train :  73 | Perplexity :  628.24284 | Per doc ppx :  771.18886 | KLD :   30.14245
# Epoch test  :  73 | Perplexity :  827.32777 | Per doc ppx :  926.59868 | KLD :   27.50652
#
# Epoch train :  74 | Perplexity :  628.23378 | Per doc ppx :  770.38707 | KLD :   30.13037
# Epoch train :  74 | Perplexity :  628.50972 | Per doc ppx :  770.17971 | KLD :   30.25354
# Epoch test  :  74 | Perplexity :  828.50593 | Per doc ppx :  925.21012 | KLD :   27.58142
#
# Epoch train :  75 | Perplexity :  628.50508 | Per doc ppx :  771.81547 | KLD :   30.21311
# Epoch train :  75 | Perplexity :  628.18641 | Per doc ppx :  768.47189 | KLD :   30.32075
# Epoch test  :  75 | Perplexity :  827.85016 | Per doc ppx :  924.35648 | KLD :   28.05999
#
# Epoch train :  76 | Perplexity :  627.60190 | Per doc ppx :  768.39402 | KLD :   30.76974
# Epoch train :  76 | Perplexity :  627.44823 | Per doc ppx :  768.26185 | KLD :   30.42721
# Epoch test  :  76 | Perplexity :  827.27902 | Per doc ppx :  925.10659 | KLD :   27.65529
#
# Epoch train :  77 | Perplexity :  626.77070 | Per doc ppx :  768.05663 | KLD :   30.46656
# Epoch train :  77 | Perplexity :  627.56809 | Per doc ppx :  768.75242 | KLD :   30.54641
# Epoch test  :  77 | Perplexity :  829.65592 | Per doc ppx :  928.72160 | KLD :   27.69757
#
# Epoch train :  78 | Perplexity :  626.43100 | Per doc ppx :  764.81342 | KLD :   30.33930
# Epoch train :  78 | Perplexity :  627.29531 | Per doc ppx :  767.31717 | KLD :   30.44480
# Epoch test  :  78 | Perplexity :  830.27595 | Per doc ppx :  925.64223 | KLD :   27.78066
#
# Epoch train :  79 | Perplexity :  627.63577 | Per doc ppx :  767.81319 | KLD :   30.42903
# Epoch train :  79 | Perplexity :  626.98619 | Per doc ppx :  766.80506 | KLD :   30.43005
# Epoch test  :  79 | Perplexity :  829.17635 | Per doc ppx :  926.69939 | KLD :   27.52115
#
# Epoch train :  80 | Perplexity :  626.39573 | Per doc ppx :  767.19598 | KLD :   30.17360
# Epoch train :  80 | Perplexity :  626.79841 | Per doc ppx :  767.56230 | KLD :   30.44784
# Epoch test  :  80 | Perplexity :  828.98016 | Per doc ppx :  923.56968 | KLD :   27.89934
#
# Epoch train :  81 | Perplexity :  626.13969 | Per doc ppx :  767.48626 | KLD :   30.53492
# Epoch train :  81 | Perplexity :  626.40933 | Per doc ppx :  767.78017 | KLD :   30.45164
# Epoch test  :  81 | Perplexity :  827.97023 | Per doc ppx :  924.77282 | KLD :   27.85221
#
# Epoch train :  82 | Perplexity :  626.57781 | Per doc ppx :  765.30495 | KLD :   30.51109
# Epoch train :  82 | Perplexity :  625.61574 | Per doc ppx :  765.60640 | KLD :   30.46424
# Epoch test  :  82 | Perplexity :  830.72589 | Per doc ppx :  927.60529 | KLD :   27.70366
#
# Epoch train :  83 | Perplexity :  625.63313 | Per doc ppx :  765.70887 | KLD :   30.30295
# Epoch train :  83 | Perplexity :  625.59365 | Per doc ppx :  765.59676 | KLD :   30.49378
# Epoch test  :  83 | Perplexity :  831.03042 | Per doc ppx :  927.49789 | KLD :   27.80117
#
# Epoch train :  84 | Perplexity :  625.12772 | Per doc ppx :  764.46512 | KLD :   30.39995
# Epoch train :  84 | Perplexity :  625.66890 | Per doc ppx :  762.80659 | KLD :   30.55618
# Epoch test  :  84 | Perplexity :  829.23881 | Per doc ppx :  925.34963 | KLD :   27.84600
#
# Epoch train :  85 | Perplexity :  624.08771 | Per doc ppx :  762.21482 | KLD :   30.47363
# Epoch train :  85 | Perplexity :  624.86269 | Per doc ppx :  763.02797 | KLD :   30.55246
# Epoch test  :  85 | Perplexity :  827.61695 | Per doc ppx :  922.66235 | KLD :   27.77313
#
# Epoch train :  86 | Perplexity :  624.86703 | Per doc ppx :  761.62749 | KLD :   30.40494
# Epoch train :  86 | Perplexity :  624.81809 | Per doc ppx :  763.06327 | KLD :   30.60466
# Epoch test  :  86 | Perplexity :  829.24270 | Per doc ppx :  928.58038 | KLD :   27.87457
#
# Epoch train :  87 | Perplexity :  625.48501 | Per doc ppx :  763.57130 | KLD :   30.52494
# Epoch train :  87 | Perplexity :  624.41133 | Per doc ppx :  760.99287 | KLD :   30.61181
# Epoch test  :  87 | Perplexity :  828.61426 | Per doc ppx :  923.93200 | KLD :   28.30679
#
# Epoch train :  88 | Perplexity :  624.71090 | Per doc ppx :  761.76785 | KLD :   30.96354
# Epoch train :  88 | Perplexity :  625.23756 | Per doc ppx :  763.93436 | KLD :   30.75046
# Epoch test  :  88 | Perplexity :  829.26814 | Per doc ppx :  924.82181 | KLD :   28.10660
#
# Epoch train :  89 | Perplexity :  623.91446 | Per doc ppx :  760.70184 | KLD :   30.77448
# Epoch train :  89 | Perplexity :  624.30858 | Per doc ppx :  763.06529 | KLD :   30.71295
# Epoch test  :  89 | Perplexity :  828.92203 | Per doc ppx :  923.43917 | KLD :   27.82744
#
# Epoch train :  90 | Perplexity :  624.03357 | Per doc ppx :  760.68252 | KLD :   30.48747
# Epoch train :  90 | Perplexity :  623.80743 | Per doc ppx :  759.54401 | KLD :   30.69908
# Epoch test  :  90 | Perplexity :  829.70927 | Per doc ppx :  924.02918 | KLD :   27.92525
#
# Epoch train :  91 | Perplexity :  623.80078 | Per doc ppx :  761.51183 | KLD :   30.55594
# Epoch train :  91 | Perplexity :  624.34628 | Per doc ppx :  760.39670 | KLD :   30.80631
# Epoch test  :  91 | Perplexity :  831.56504 | Per doc ppx :  926.82952 | KLD :   28.17692
#
# Epoch train :  92 | Perplexity :  623.41345 | Per doc ppx :  760.11497 | KLD :   30.75165
# Epoch train :  92 | Perplexity :  623.35751 | Per doc ppx :  757.90410 | KLD :   30.77760
# Epoch test  :  92 | Perplexity :  832.07795 | Per doc ppx :  925.72737 | KLD :   28.04179
#
# Epoch train :  93 | Perplexity :  622.74255 | Per doc ppx :  757.32601 | KLD :   30.63426
# Epoch train :  93 | Perplexity :  623.30247 | Per doc ppx :  759.07615 | KLD :   30.65753
# Epoch test  :  93 | Perplexity :  833.56558 | Per doc ppx :  926.65746 | KLD :   27.94455
#
# Epoch train :  94 | Perplexity :  623.06297 | Per doc ppx :  758.52220 | KLD :   30.68535
# Epoch train :  94 | Perplexity :  622.62350 | Per doc ppx :  755.27568 | KLD :   30.88469
# Epoch test  :  94 | Perplexity :  829.45691 | Per doc ppx :  920.71570 | KLD :   28.00723
#
# Epoch train :  95 | Perplexity :  622.83280 | Per doc ppx :  758.21036 | KLD :   30.68536
# Epoch train :  95 | Perplexity :  622.54983 | Per doc ppx :  756.89014 | KLD :   30.81761
# Epoch test  :  95 | Perplexity :  831.33774 | Per doc ppx :  927.95691 | KLD :   28.13366
#
# Epoch train :  96 | Perplexity :  622.61127 | Per doc ppx :  758.84632 | KLD :   30.87131
# Epoch train :  96 | Perplexity :  622.22511 | Per doc ppx :  755.32323 | KLD :   30.94239
# Epoch test  :  96 | Perplexity :  829.99405 | Per doc ppx :  923.32038 | KLD :   28.23475
#
# Epoch train :  97 | Perplexity :  622.33056 | Per doc ppx :  758.68518 | KLD :   30.79354
# Epoch train :  97 | Perplexity :  622.12979 | Per doc ppx :  755.95579 | KLD :   30.83460
# Epoch test  :  97 | Perplexity :  830.99589 | Per doc ppx :  926.73404 | KLD :   28.22017
#
# Epoch train :  98 | Perplexity :  621.51268 | Per doc ppx :  754.90596 | KLD :   30.83470
# Epoch train :  98 | Perplexity :  622.04626 | Per doc ppx :  757.27251 | KLD :   30.83063
# Epoch test  :  98 | Perplexity :  830.85482 | Per doc ppx :  927.76489 | KLD :   28.23609
#
# Epoch train :  99 | Perplexity :  621.95895 | Per doc ppx :  755.96451 | KLD :   30.93703
# Epoch train :  99 | Perplexity :  621.88870 | Per doc ppx :  756.55820 | KLD :   30.91288
# Epoch test  :  99 | Perplexity :  831.04236 | Per doc ppx :  926.21759 | KLD :   28.53518
#
# Epoch train : 100 | Perplexity :  621.72610 | Per doc ppx :  757.37535 | KLD :   31.18673
# Epoch train : 100 | Perplexity :  621.38710 | Per doc ppx :  754.31436 | KLD :   30.90697
# Epoch test  : 100 | Perplexity :  832.19260 | Per doc ppx :  926.36419 | KLD :   27.98034
#
# Epoch train : 101 | Perplexity :  621.17244 | Per doc ppx :  755.20922 | KLD :   30.59957
# Epoch train : 101 | Perplexity :  622.03691 | Per doc ppx :  756.62094 | KLD :   30.97872
# Epoch test  : 101 | Perplexity :  831.60390 | Per doc ppx :  926.77608 | KLD :   28.36644
#
# Epoch train : 102 | Perplexity :  621.01142 | Per doc ppx :  753.62460 | KLD :   30.94663
# Epoch train : 102 | Perplexity :  621.41647 | Per doc ppx :  753.29164 | KLD :   30.97062
# Epoch test  : 102 | Perplexity :  832.77784 | Per doc ppx :  925.86608 | KLD :   28.25263
#
# Epoch train : 103 | Perplexity :  620.48919 | Per doc ppx :  753.32683 | KLD :   30.87421
# Epoch train : 103 | Perplexity :  621.36044 | Per doc ppx :  752.73015 | KLD :   31.02655
# Epoch test  : 103 | Perplexity :  830.82960 | Per doc ppx :  919.89479 | KLD :   28.20252
#
# Epoch train : 104 | Perplexity :  621.02798 | Per doc ppx :  756.39650 | KLD :   30.85742
# Epoch train : 104 | Perplexity :  621.11617 | Per doc ppx :  753.42514 | KLD :   31.02858
# Epoch test  : 104 | Perplexity :  831.94914 | Per doc ppx :  925.87090 | KLD :   28.23641
#
# Epoch train : 105 | Perplexity :  620.90067 | Per doc ppx :  754.12638 | KLD :   30.88481
# Epoch train : 105 | Perplexity :  621.83479 | Per doc ppx :  755.22636 | KLD :   31.08027
# Epoch test  : 105 | Perplexity :  832.47131 | Per doc ppx :  924.48848 | KLD :   28.50774
#
# Epoch train : 106 | Perplexity :  620.86068 | Per doc ppx :  752.62426 | KLD :   31.16661
# Epoch train : 106 | Perplexity :  620.46244 | Per doc ppx :  753.15646 | KLD :   31.04573
# Epoch test  : 106 | Perplexity :  832.03294 | Per doc ppx :  922.52975 | KLD :   28.39222
#
# Epoch train : 107 | Perplexity :  620.62156 | Per doc ppx :  753.89566 | KLD :   31.05960
# Epoch train : 107 | Perplexity :  621.21732 | Per doc ppx :  753.61029 | KLD :   31.06499
# Epoch test  : 107 | Perplexity :  835.08250 | Per doc ppx :  926.72047 | KLD :   28.39788
#
# Epoch train : 108 | Perplexity :  620.82588 | Per doc ppx :  753.81702 | KLD :   31.02978
# Epoch train : 108 | Perplexity :  620.85672 | Per doc ppx :  754.78668 | KLD :   31.07860
# Epoch test  : 108 | Perplexity :  833.09335 | Per doc ppx :  927.63216 | KLD :   28.17773
#
# Epoch train : 109 | Perplexity :  619.80253 | Per doc ppx :  750.97307 | KLD :   30.85530
# Epoch train : 109 | Perplexity :  620.58749 | Per doc ppx :  753.19037 | KLD :   31.15941
# Epoch test  : 109 | Perplexity :  830.94601 | Per doc ppx :  926.92625 | KLD :   28.65391
#
# Epoch train : 110 | Perplexity :  620.16438 | Per doc ppx :  752.97721 | KLD :   31.32774
# Epoch train : 110 | Perplexity :  619.83395 | Per doc ppx :  752.00342 | KLD :   31.20151
# Epoch test  : 110 | Perplexity :  831.07343 | Per doc ppx :  924.79222 | KLD :   28.19672
#
# Epoch train : 111 | Perplexity :  619.79534 | Per doc ppx :  752.74205 | KLD :   30.80526
# Epoch train : 111 | Perplexity :  619.06768 | Per doc ppx :  749.13464 | KLD :   31.01607
# Epoch test  : 111 | Perplexity :  832.47189 | Per doc ppx :  924.95678 | KLD :   28.43336
#
# Epoch train : 112 | Perplexity :  619.36257 | Per doc ppx :  751.21011 | KLD :   31.08298
# Epoch train : 112 | Perplexity :  620.23331 | Per doc ppx :  752.41352 | KLD :   31.14995
# Epoch test  : 112 | Perplexity :  831.86504 | Per doc ppx :  926.19658 | KLD :   28.58412
#
# Epoch train : 113 | Perplexity :  619.28568 | Per doc ppx :  750.76025 | KLD :   31.15996
# Epoch train : 113 | Perplexity :  619.43416 | Per doc ppx :  752.34032 | KLD :   31.11699
# Epoch test  : 113 | Perplexity :  831.55903 | Per doc ppx :  924.64121 | KLD :   28.74626
#
# Epoch train : 114 | Perplexity :  619.39890 | Per doc ppx :  751.09219 | KLD :   31.30206
# Epoch train : 114 | Perplexity :  618.94730 | Per doc ppx :  749.46043 | KLD :   31.05772
# Epoch test  : 114 | Perplexity :  831.72662 | Per doc ppx :  919.09485 | KLD :   28.58672
#
# Epoch train : 115 | Perplexity :  619.62163 | Per doc ppx :  753.46501 | KLD :   31.24228
# Epoch train : 115 | Perplexity :  619.44659 | Per doc ppx :  750.83455 | KLD :   31.26031
# Epoch test  : 115 | Perplexity :  835.75602 | Per doc ppx :  929.98768 | KLD :   28.55976
#
# Epoch train : 116 | Perplexity :  618.94622 | Per doc ppx :  750.38432 | KLD :   31.20148
# Epoch train : 116 | Perplexity :  619.39455 | Per doc ppx :  752.35654 | KLD :   31.28910
# Epoch test  : 116 | Perplexity :  833.77084 | Per doc ppx :  927.32432 | KLD :   28.89513
#
# Epoch train : 117 | Perplexity :  618.03400 | Per doc ppx :  747.21948 | KLD :   31.51591
# Epoch train : 117 | Perplexity :  618.75784 | Per doc ppx :  749.44193 | KLD :   31.18555
# Epoch test  : 117 | Perplexity :  832.03243 | Per doc ppx :  921.31065 | KLD :   28.41275
#
# Epoch train : 118 | Perplexity :  618.14755 | Per doc ppx :  746.70103 | KLD :   31.01367
# Epoch train : 118 | Perplexity :  618.95828 | Per doc ppx :  749.74826 | KLD :   31.20851
# Epoch test  : 118 | Perplexity :  834.21765 | Per doc ppx :  927.90941 | KLD :   28.57666
#
# Epoch train : 119 | Perplexity :  618.40561 | Per doc ppx :  751.54686 | KLD :   31.16565
# Epoch train : 119 | Perplexity :  618.48391 | Per doc ppx :  752.96004 | KLD :   31.16596
# Epoch test  : 119 | Perplexity :  832.04341 | Per doc ppx :  923.28722 | KLD :   28.73768
#
# Epoch train : 120 | Perplexity :  617.72347 | Per doc ppx :  747.53605 | KLD :   31.39547
# Epoch train : 120 | Perplexity :  617.88305 | Per doc ppx :  750.20260 | KLD :   31.23647
# Epoch test  : 120 | Perplexity :  833.39367 | Per doc ppx :  925.03301 | KLD :   28.63304
#
# Epoch train : 121 | Perplexity :  617.80365 | Per doc ppx :  746.58353 | KLD :   31.39929
# Epoch train : 121 | Perplexity :  618.49692 | Per doc ppx :  750.49334 | KLD :   31.35803
# Epoch test  : 121 | Perplexity :  833.84908 | Per doc ppx :  925.07874 | KLD :   28.69388
#
# Epoch train : 122 | Perplexity :  618.23248 | Per doc ppx :  749.64365 | KLD :   31.37758
# Epoch train : 122 | Perplexity :  617.34385 | Per doc ppx :  748.06740 | KLD :   31.29011
# Epoch test  : 122 | Perplexity :  833.35677 | Per doc ppx :  925.38696 | KLD :   28.71888
#
# Epoch train : 123 | Perplexity :  616.64466 | Per doc ppx :  745.98334 | KLD :   31.36562
# Epoch train : 123 | Perplexity :  617.85333 | Per doc ppx :  747.56783 | KLD :   31.34129
# Epoch test  : 123 | Perplexity :  833.59009 | Per doc ppx :  922.44006 | KLD :   28.51780
#
# Epoch train : 124 | Perplexity :  617.73017 | Per doc ppx :  748.59065 | KLD :   31.13563
# Epoch train : 124 | Perplexity :  617.52529 | Per doc ppx :  750.03342 | KLD :   31.24443
# Epoch test  : 124 | Perplexity :  833.11454 | Per doc ppx :  924.68316 | KLD :   28.76113
#
# Epoch train : 125 | Perplexity :  617.25749 | Per doc ppx :  749.61037 | KLD :   31.37086
# Epoch train : 125 | Perplexity :  617.82062 | Per doc ppx :  749.00165 | KLD :   31.29036
# Epoch test  : 125 | Perplexity :  834.77266 | Per doc ppx :  921.17863 | KLD :   28.77377
#
# Epoch train : 126 | Perplexity :  617.45227 | Per doc ppx :  745.70018 | KLD :   31.40314
# Epoch train : 126 | Perplexity :  617.82769 | Per doc ppx :  747.12591 | KLD :   31.41631
# Epoch test  : 126 | Perplexity :  833.91876 | Per doc ppx :  923.77451 | KLD :   28.57495
#
# Epoch train : 127 | Perplexity :  617.17495 | Per doc ppx :  747.73321 | KLD :   31.30304
# Epoch train : 127 | Perplexity :  617.58848 | Per doc ppx :  747.65762 | KLD :   31.39894
# Epoch test  : 127 | Perplexity :  835.53888 | Per doc ppx :  924.30797 | KLD :   28.79516
#
# Epoch train : 128 | Perplexity :  616.86053 | Per doc ppx :  745.82942 | KLD :   31.39609
# Epoch train : 128 | Perplexity :  616.73532 | Per doc ppx :  746.08809 | KLD :   31.33687
# Epoch test  : 128 | Perplexity :  834.45056 | Per doc ppx :  920.41755 | KLD :   28.67248
#
# Epoch train : 129 | Perplexity :  616.55898 | Per doc ppx :  745.30060 | KLD :   31.30885
# Epoch train : 129 | Perplexity :  617.03869 | Per doc ppx :  745.78086 | KLD :   31.39651
# Epoch test  : 129 | Perplexity :  833.81700 | Per doc ppx :  920.35993 | KLD :   28.48987
#
# Epoch train : 130 | Perplexity :  616.64841 | Per doc ppx :  745.42860 | KLD :   31.07515
# Epoch train : 130 | Perplexity :  616.94150 | Per doc ppx :  746.74796 | KLD :   31.33813
# Epoch test  : 130 | Perplexity :  833.75123 | Per doc ppx :  923.67208 | KLD :   28.76690
#
# Epoch train : 131 | Perplexity :  616.58230 | Per doc ppx :  744.62380 | KLD :   31.45103
# Epoch train : 131 | Perplexity :  616.55959 | Per doc ppx :  746.21327 | KLD :   31.39754
# Epoch test  : 131 | Perplexity :  834.63431 | Per doc ppx :  923.68967 | KLD :   28.57994
#
# Epoch train : 132 | Perplexity :  615.76989 | Per doc ppx :  742.82443 | KLD :   31.19810
# Epoch train : 132 | Perplexity :  616.32008 | Per doc ppx :  744.29558 | KLD :   31.40117
# Epoch test  : 132 | Perplexity :  835.43594 | Per doc ppx :  925.14623 | KLD :   28.65273
#
# Epoch train : 133 | Perplexity :  616.19943 | Per doc ppx :  745.53333 | KLD :   31.27625
# Epoch train : 133 | Perplexity :  616.55957 | Per doc ppx :  744.32179 | KLD :   31.43603
# Epoch test  : 133 | Perplexity :  832.62135 | Per doc ppx :  924.41058 | KLD :   28.50630
#
# Epoch train : 134 | Perplexity :  616.05438 | Per doc ppx :  746.34912 | KLD :   31.21502
# Epoch train : 134 | Perplexity :  616.17966 | Per doc ppx :  745.12214 | KLD :   31.45764
# Epoch test  : 134 | Perplexity :  833.86882 | Per doc ppx :  919.47522 | KLD :   28.52503
#
# Epoch train : 135 | Perplexity :  615.87291 | Per doc ppx :  745.61689 | KLD :   31.13964
# Epoch train : 135 | Perplexity :  616.65844 | Per doc ppx :  746.13199 | KLD :   31.45556
# Epoch test  : 135 | Perplexity :  832.42777 | Per doc ppx :  919.65272 | KLD :   28.59493
#
# Epoch train : 136 | Perplexity :  615.62574 | Per doc ppx :  742.78992 | KLD :   31.21075
# Epoch train : 136 | Perplexity :  615.52520 | Per doc ppx :  743.27128 | KLD :   31.36067
# Epoch test  : 136 | Perplexity :  832.16486 | Per doc ppx :  918.92020 | KLD :   28.73571
#
# Epoch train : 137 | Perplexity :  615.45161 | Per doc ppx :  743.24253 | KLD :   31.43430
# Epoch train : 137 | Perplexity :  616.05565 | Per doc ppx :  744.62287 | KLD :   31.55242
# Epoch test  : 137 | Perplexity :  831.04068 | Per doc ppx :  921.62557 | KLD :   28.94728
#
# Epoch train : 138 | Perplexity :  615.42428 | Per doc ppx :  743.77811 | KLD :   31.54969
# Epoch train : 138 | Perplexity :  615.42276 | Per doc ppx :  743.24422 | KLD :   31.36507
# Epoch test  : 138 | Perplexity :  833.49042 | Per doc ppx :  921.32599 | KLD :   28.73354
#
# Epoch train : 139 | Perplexity :  615.21786 | Per doc ppx :  742.21435 | KLD :   31.35185
# Epoch train : 139 | Perplexity :  614.36174 | Per doc ppx :  741.52503 | KLD :   31.38222
# Epoch test  : 139 | Perplexity :  833.33082 | Per doc ppx :  925.06345 | KLD :   28.89194
#
# Epoch train : 140 | Perplexity :  615.40077 | Per doc ppx :  742.54593 | KLD :   31.47341
# Epoch train : 140 | Perplexity :  615.60947 | Per doc ppx :  743.33747 | KLD :   31.45390
# Epoch test  : 140 | Perplexity :  832.36796 | Per doc ppx :  920.92005 | KLD :   28.93198
#
# Epoch train : 141 | Perplexity :  615.39890 | Per doc ppx :  743.25347 | KLD :   31.48569
# Epoch train : 141 | Perplexity :  615.20353 | Per doc ppx :  743.34570 | KLD :   31.35666
# Epoch test  : 141 | Perplexity :  835.25547 | Per doc ppx :  925.74314 | KLD :   28.82031
#
# Epoch train : 142 | Perplexity :  615.88341 | Per doc ppx :  744.90417 | KLD :   31.51449
# Epoch train : 142 | Perplexity :  615.62382 | Per doc ppx :  743.69441 | KLD :   31.59093
# Epoch test  : 142 | Perplexity :  833.60008 | Per doc ppx :  919.96557 | KLD :   28.82455
#
# Epoch train : 143 | Perplexity :  614.60959 | Per doc ppx :  741.60788 | KLD :   31.49803
# Epoch train : 143 | Perplexity :  614.69461 | Per doc ppx :  742.18301 | KLD :   31.48030
# Epoch test  : 143 | Perplexity :  833.73156 | Per doc ppx :  922.13504 | KLD :   28.88859
#
# Epoch train : 144 | Perplexity :  614.40898 | Per doc ppx :  741.64131 | KLD :   31.45580
# Epoch train : 144 | Perplexity :  614.74353 | Per doc ppx :  740.62674 | KLD :   31.40920
# Epoch test  : 144 | Perplexity :  831.14891 | Per doc ppx :  918.80119 | KLD :   28.77188
#
# Epoch train : 145 | Perplexity :  615.02879 | Per doc ppx :  743.97673 | KLD :   31.39616
# Epoch train : 145 | Perplexity :  614.72500 | Per doc ppx :  742.05157 | KLD :   31.48298
# Epoch test  : 145 | Perplexity :  834.64793 | Per doc ppx :  924.95938 | KLD :   28.94721
#
# Epoch train : 146 | Perplexity :  614.56256 | Per doc ppx :  741.60310 | KLD :   31.56898
# Epoch train : 146 | Perplexity :  614.74588 | Per doc ppx :  742.23712 | KLD :   31.50411
# Epoch test  : 146 | Perplexity :  834.42916 | Per doc ppx :  918.02943 | KLD :   28.82531
#
# Epoch train : 147 | Perplexity :  614.06045 | Per doc ppx :  740.38438 | KLD :   31.43333
# Epoch train : 147 | Perplexity :  613.93529 | Per doc ppx :  740.48520 | KLD :   31.40508
# Epoch test  : 147 | Perplexity :  833.93923 | Per doc ppx :  920.43729 | KLD :   28.88234
#
# Epoch train : 148 | Perplexity :  613.66185 | Per doc ppx :  739.16908 | KLD :   31.46219
# Epoch train : 148 | Perplexity :  613.84397 | Per doc ppx :  738.68020 | KLD :   31.42511
# Epoch test  : 148 | Perplexity :  833.04930 | Per doc ppx :  917.32435 | KLD :   29.13221
#
# Epoch train : 149 | Perplexity :  613.62362 | Per doc ppx :  740.54262 | KLD :   31.71882
# Epoch train : 149 | Perplexity :  613.42781 | Per doc ppx :  737.48743 | KLD :   31.44023
# Epoch test  : 149 | Perplexity :  834.28722 | Per doc ppx :  923.35910 | KLD :   28.87716
#
# Epoch train : 150 | Perplexity :  613.57306 | Per doc ppx :  738.45766 | KLD :   31.59243
# Epoch train : 150 | Perplexity :  614.39521 | Per doc ppx :  740.55319 | KLD :   31.64789
# Epoch test  : 150 | Perplexity :  834.39332 | Per doc ppx :  921.35168 | KLD :   29.04101
#
# Epoch train : 151 | Perplexity :  613.10048 | Per doc ppx :  738.62910 | KLD :   31.61012
# Epoch train : 151 | Perplexity :  614.17362 | Per doc ppx :  742.03670 | KLD :   31.48038
# Epoch test  : 151 | Perplexity :  832.32689 | Per doc ppx :  918.33162 | KLD :   29.00886
#
# Epoch train : 152 | Perplexity :  613.30564 | Per doc ppx :  738.78112 | KLD :   31.62225
# Epoch train : 152 | Perplexity :  613.56293 | Per doc ppx :  738.71777 | KLD :   31.53268
# Epoch test  : 152 | Perplexity :  836.81279 | Per doc ppx :  923.88569 | KLD :   29.19980
#
# Epoch train : 153 | Perplexity :  613.67216 | Per doc ppx :  738.87497 | KLD :   31.80424
# Epoch train : 153 | Perplexity :  613.48560 | Per doc ppx :  737.70346 | KLD :   31.51199
# Epoch test  : 153 | Perplexity :  832.12570 | Per doc ppx :  917.97144 | KLD :   28.84771
#
# Epoch train : 154 | Perplexity :  613.91916 | Per doc ppx :  739.00968 | KLD :   31.39308
# Epoch train : 154 | Perplexity :  612.71069 | Per doc ppx :  736.08295 | KLD :   31.35208
# Epoch test  : 154 | Perplexity :  833.05809 | Per doc ppx :  917.54343 | KLD :   28.79306
#
# Epoch train : 155 | Perplexity :  612.97734 | Per doc ppx :  738.97453 | KLD :   31.34700
# Epoch train : 155 | Perplexity :  613.59865 | Per doc ppx :  739.51420 | KLD :   31.48989
# Epoch test  : 155 | Perplexity :  833.99076 | Per doc ppx :  920.82208 | KLD :   28.67790
#
# Epoch train : 156 | Perplexity :  613.57938 | Per doc ppx :  738.78669 | KLD :   31.30203
# Epoch train : 156 | Perplexity :  613.20128 | Per doc ppx :  739.03661 | KLD :   31.51806
# Epoch test  : 156 | Perplexity :  832.03809 | Per doc ppx :  918.24810 | KLD :   28.58354
#
# Epoch train : 157 | Perplexity :  612.52407 | Per doc ppx :  738.48907 | KLD :   31.22766
# Epoch train : 157 | Perplexity :  613.44400 | Per doc ppx :  739.11026 | KLD :   31.54142
# Epoch test  : 157 | Perplexity :  834.27467 | Per doc ppx :  920.58437 | KLD :   28.89228
#
# Epoch train : 158 | Perplexity :  612.43834 | Per doc ppx :  737.91063 | KLD :   31.46035
# Epoch train : 158 | Perplexity :  613.33039 | Per doc ppx :  737.38336 | KLD :   31.51139
# Epoch test  : 158 | Perplexity :  837.02128 | Per doc ppx :  919.90426 | KLD :   28.73135
#
# Epoch train : 159 | Perplexity :  612.40572 | Per doc ppx :  735.28024 | KLD :   31.40008
# Epoch train : 159 | Perplexity :  612.90317 | Per doc ppx :  737.49425 | KLD :   31.54014
# Epoch test  : 159 | Perplexity :  834.98346 | Per doc ppx :  920.25592 | KLD :   28.97135
#
# Epoch train : 160 | Perplexity :  612.63256 | Per doc ppx :  737.02759 | KLD :   31.58499
# Epoch train : 160 | Perplexity :  612.69788 | Per doc ppx :  737.89174 | KLD :   31.50925
# Epoch test  : 160 | Perplexity :  834.98116 | Per doc ppx :  920.28972 | KLD :   28.98150
#
# Epoch train : 161 | Perplexity :  612.30099 | Per doc ppx :  736.11195 | KLD :   31.66724
# Epoch train : 161 | Perplexity :  612.55085 | Per doc ppx :  738.41039 | KLD :   31.56866
# Epoch test  : 161 | Perplexity :  835.01010 | Per doc ppx :  920.12509 | KLD :   28.66606
#
# Epoch train : 162 | Perplexity :  612.94065 | Per doc ppx :  737.40044 | KLD :   31.27749
# Epoch train : 162 | Perplexity :  612.61139 | Per doc ppx :  736.10082 | KLD :   31.55759
# Epoch test  : 162 | Perplexity :  831.67805 | Per doc ppx :  916.61467 | KLD :   28.84568
#
# Epoch train : 163 | Perplexity :  611.58718 | Per doc ppx :  733.21323 | KLD :   31.44220
# Epoch train : 163 | Perplexity :  612.63495 | Per doc ppx :  737.52644 | KLD :   31.54387
# Epoch test  : 163 | Perplexity :  832.68612 | Per doc ppx :  917.98377 | KLD :   29.26976
#
# Epoch train : 164 | Perplexity :  612.34343 | Per doc ppx :  736.29325 | KLD :   31.83220
# Epoch train : 164 | Perplexity :  612.00263 | Per doc ppx :  736.49732 | KLD :   31.52489
# Epoch test  : 164 | Perplexity :  831.55285 | Per doc ppx :  917.88014 | KLD :   28.86877
#
# Epoch train : 165 | Perplexity :  612.35981 | Per doc ppx :  737.61894 | KLD :   31.41651
# Epoch train : 165 | Perplexity :  611.75833 | Per doc ppx :  735.13427 | KLD :   31.42001
# Epoch test  : 165 | Perplexity :  832.64142 | Per doc ppx :  920.18551 | KLD :   28.77685
#
# Epoch train : 166 | Perplexity :  611.85798 | Per doc ppx :  736.10011 | KLD :   31.40899
# Epoch train : 166 | Perplexity :  613.10725 | Per doc ppx :  739.01573 | KLD :   31.58375
# Epoch test  : 166 | Perplexity :  834.73182 | Per doc ppx :  918.11815 | KLD :   29.13809
#
# Epoch train : 167 | Perplexity :  612.95009 | Per doc ppx :  737.32962 | KLD :   31.76611
# Epoch train : 167 | Perplexity :  612.10025 | Per doc ppx :  734.05940 | KLD :   31.56950
# Epoch test  : 167 | Perplexity :  831.73908 | Per doc ppx :  916.06569 | KLD :   29.11007
#
# Epoch train : 168 | Perplexity :  611.69985 | Per doc ppx :  735.66327 | KLD :   31.69263
# Epoch train : 168 | Perplexity :  611.89554 | Per doc ppx :  734.53344 | KLD :   31.54105
# Epoch test  : 168 | Perplexity :  832.62419 | Per doc ppx :  919.92799 | KLD :   29.08233
#
# Epoch train : 169 | Perplexity :  611.02826 | Per doc ppx :  733.71807 | KLD :   31.63959
# Epoch train : 169 | Perplexity :  611.44008 | Per doc ppx :  734.76510 | KLD :   31.49305
# Epoch test  : 169 | Perplexity :  833.98511 | Per doc ppx :  916.35487 | KLD :   29.07993
#
# Epoch train : 170 | Perplexity :  610.69349 | Per doc ppx :  732.47454 | KLD :   31.75663
# Epoch train : 170 | Perplexity :  611.87335 | Per doc ppx :  735.91014 | KLD :   31.63539
# Epoch test  : 170 | Perplexity :  833.91507 | Per doc ppx :  919.38495 | KLD :   29.06559
#
# Epoch train : 171 | Perplexity :  611.37785 | Per doc ppx :  733.45103 | KLD :   31.62541
# Epoch train : 171 | Perplexity :  612.08958 | Per doc ppx :  734.41133 | KLD :   31.58973
# Epoch test  : 171 | Perplexity :  833.93056 | Per doc ppx :  919.42863 | KLD :   28.88141
#
# Epoch train : 172 | Perplexity :  611.79184 | Per doc ppx :  736.28090 | KLD :   31.52436
# Epoch train : 172 | Perplexity :  611.42587 | Per doc ppx :  734.47682 | KLD :   31.58898
# Epoch test  : 172 | Perplexity :  833.89189 | Per doc ppx :  917.22089 | KLD :   29.17784
#
# Epoch train : 173 | Perplexity :  610.74612 | Per doc ppx :  732.27970 | KLD :   31.70088
# Epoch train : 173 | Perplexity :  611.32638 | Per doc ppx :  732.14905 | KLD :   31.46984
# Epoch test  : 173 | Perplexity :  832.17904 | Per doc ppx :  916.14920 | KLD :   28.85743
#
# Epoch train : 174 | Perplexity :  610.98228 | Per doc ppx :  734.38254 | KLD :   31.46386
# Epoch train : 174 | Perplexity :  611.66553 | Per doc ppx :  733.88707 | KLD :   31.56310
# Epoch test  : 174 | Perplexity :  833.93574 | Per doc ppx :  917.53396 | KLD :   28.99326
#
# Epoch train : 175 | Perplexity :  611.02201 | Per doc ppx :  732.11442 | KLD :   31.66328
# Epoch train : 175 | Perplexity :  610.66836 | Per doc ppx :  731.56713 | KLD :   31.55614
# Epoch test  : 175 | Perplexity :  831.41302 | Per doc ppx :  918.13728 | KLD :   29.12457
#
# Epoch train : 176 | Perplexity :  611.13580 | Per doc ppx :  735.93071 | KLD :   31.73068
# Epoch train : 176 | Perplexity :  610.53005 | Per doc ppx :  732.68967 | KLD :   31.55789
# Epoch test  : 176 | Perplexity :  834.43395 | Per doc ppx :  917.27130 | KLD :   28.92241
#
# Epoch train : 177 | Perplexity :  610.83193 | Per doc ppx :  734.26478 | KLD :   31.63940
# Epoch train : 177 | Perplexity :  610.83338 | Per doc ppx :  734.56721 | KLD :   31.64858
# Epoch test  : 177 | Perplexity :  833.30823 | Per doc ppx :  917.85977 | KLD :   29.12427
#
# ...
#
# Epoch train : 942 | Perplexity :  589.28446 | Per doc ppx :  686.68441 | KLD :   30.81545
# Epoch train : 942 | Perplexity :  589.55761 | Per doc ppx :  686.78217 | KLD :   30.80075
# Epoch test  : 942 | Perplexity :  817.44738 | Per doc ppx :  884.73869 | KLD :   28.19627
#
# Epoch train : 943 | Perplexity :  589.55826 | Per doc ppx :  687.01266 | KLD :   31.05614
# Epoch train : 943 | Perplexity :  589.70281 | Per doc ppx :  688.59300 | KLD :   30.86763
# Epoch test  : 943 | Perplexity :  815.64533 | Per doc ppx :  882.94841 | KLD :   28.09670
#
# Epoch train : 944 | Perplexity :  589.33080 | Per doc ppx :  687.57909 | KLD :   30.94472
# Epoch train : 944 | Perplexity :  588.77267 | Per doc ppx :  686.30561 | KLD :   30.74443
# Epoch test  : 944 | Perplexity :  815.40468 | Per doc ppx :  880.31653 | KLD :   27.69696
#
# Epoch train : 945 | Perplexity :  589.76430 | Per doc ppx :  688.26262 | KLD :   30.60218
# Epoch train : 945 | Perplexity :  589.66472 | Per doc ppx :  687.05007 | KLD :   30.90354
# Epoch test  : 945 | Perplexity :  816.01305 | Per doc ppx :  882.19557 | KLD :   28.16132
#
# Epoch train : 946 | Perplexity :  589.31254 | Per doc ppx :  686.11700 | KLD :   31.00415
# Epoch train : 946 | Perplexity :  589.34898 | Per doc ppx :  686.69841 | KLD :   30.80710
# Epoch test  : 946 | Perplexity :  814.27727 | Per doc ppx :  881.51280 | KLD :   28.00870
#
# Epoch train : 947 | Perplexity :  588.95785 | Per doc ppx :  685.59415 | KLD :   30.84742
# Epoch train : 947 | Perplexity :  589.60888 | Per doc ppx :  687.48101 | KLD :   30.81369
# Epoch test  : 947 | Perplexity :  816.30458 | Per doc ppx :  883.99139 | KLD :   27.79988
#
# Epoch train : 948 | Perplexity :  589.39019 | Per doc ppx :  687.79819 | KLD :   30.74055
# Epoch train : 948 | Perplexity :  588.97577 | Per doc ppx :  687.01106 | KLD :   30.83951
# Epoch test  : 948 | Perplexity :  815.72834 | Per doc ppx :  881.66892 | KLD :   28.11629
#
# Epoch train : 949 | Perplexity :  589.35804 | Per doc ppx :  686.48193 | KLD :   30.97228
# Epoch train : 949 | Perplexity :  589.80951 | Per doc ppx :  686.71003 | KLD :   30.85188
# Epoch test  : 949 | Perplexity :  817.65056 | Per doc ppx :  885.76876 | KLD :   27.98009
#
# Epoch train : 950 | Perplexity :  589.35814 | Per doc ppx :  684.55020 | KLD :   30.88428
# Epoch train : 950 | Perplexity :  589.64105 | Per doc ppx :  687.25063 | KLD :   30.86308
# Epoch test  : 950 | Perplexity :  819.22611 | Per doc ppx :  886.81253 | KLD :   28.12346
#
# Epoch train : 951 | Perplexity :  589.19424 | Per doc ppx :  687.28857 | KLD :   30.96714
# Epoch train : 951 | Perplexity :  589.64200 | Per doc ppx :  687.43967 | KLD :   30.82933
# Epoch test  : 951 | Perplexity :  816.90494 | Per doc ppx :  883.41123 | KLD :   27.88087
#
# Epoch train : 952 | Perplexity :  589.32240 | Per doc ppx :  686.19134 | KLD :   30.82688
# Epoch train : 952 | Perplexity :  588.94753 | Per doc ppx :  686.60209 | KLD :   30.87655
# Epoch test  : 952 | Perplexity :  819.43888 | Per doc ppx :  886.76435 | KLD :   28.00210
#
# Epoch train : 953 | Perplexity :  589.73831 | Per doc ppx :  686.80337 | KLD :   30.82344
# Epoch train : 953 | Perplexity :  588.80673 | Per doc ppx :  683.49271 | KLD :   30.72431
# Epoch test  : 953 | Perplexity :  817.54838 | Per doc ppx :  883.69494 | KLD :   27.81475
#
# Epoch train : 954 | Perplexity :  589.06913 | Per doc ppx :  686.92192 | KLD :   30.65890
# Epoch train : 954 | Perplexity :  589.53936 | Per doc ppx :  688.48955 | KLD :   30.82697
# Epoch test  : 954 | Perplexity :  816.06326 | Per doc ppx :  883.26127 | KLD :   27.91640
#
# Epoch train : 955 | Perplexity :  589.30484 | Per doc ppx :  686.85438 | KLD :   30.79149
# Epoch train : 955 | Perplexity :  589.81651 | Per doc ppx :  687.80493 | KLD :   30.84432
# Epoch test  : 955 | Perplexity :  813.97431 | Per doc ppx :  883.24547 | KLD :   27.97756
#
# Epoch train : 956 | Perplexity :  589.45086 | Per doc ppx :  686.77482 | KLD :   30.90484
# Epoch train : 956 | Perplexity :  589.28017 | Per doc ppx :  686.14953 | KLD :   30.88316
# Epoch test  : 956 | Perplexity :  818.81727 | Per doc ppx :  886.75769 | KLD :   28.00582
#
# Epoch train : 957 | Perplexity :  588.77259 | Per doc ppx :  684.87489 | KLD :   30.84938
# Epoch train : 957 | Perplexity :  589.68044 | Per doc ppx :  686.14234 | KLD :   30.86274
# Epoch test  : 957 | Perplexity :  814.16091 | Per doc ppx :  881.06382 | KLD :   27.96291
#
# Epoch train : 958 | Perplexity :  589.06635 | Per doc ppx :  686.35830 | KLD :   30.87431
# Epoch train : 958 | Perplexity :  589.39440 | Per doc ppx :  687.69221 | KLD :   30.86669
# Epoch test  : 958 | Perplexity :  815.50353 | Per doc ppx :  883.43350 | KLD :   27.94308
#
# Epoch train : 959 | Perplexity :  589.32960 | Per doc ppx :  686.34213 | KLD :   30.79633
# Epoch train : 959 | Perplexity :  589.44470 | Per doc ppx :  687.67899 | KLD :   30.87820
# Epoch test  : 959 | Perplexity :  816.83698 | Per doc ppx :  882.26417 | KLD :   27.91941
#
# Epoch train : 960 | Perplexity :  589.24648 | Per doc ppx :  685.71483 | KLD :   30.81615
# Epoch train : 960 | Perplexity :  589.42157 | Per doc ppx :  686.12481 | KLD :   30.85564
# Epoch test  : 960 | Perplexity :  814.47352 | Per doc ppx :  883.52013 | KLD :   28.02161
#
# Epoch train : 961 | Perplexity :  589.69413 | Per doc ppx :  687.84988 | KLD :   30.88035
# Epoch train : 961 | Perplexity :  589.24441 | Per doc ppx :  687.61288 | KLD :   30.77598
# Epoch test  : 961 | Perplexity :  817.36607 | Per doc ppx :  883.60278 | KLD :   27.89455
#
# Epoch train : 962 | Perplexity :  589.19459 | Per doc ppx :  685.96436 | KLD :   30.74426
# Epoch train : 962 | Perplexity :  589.45354 | Per doc ppx :  685.59623 | KLD :   30.80560
# Epoch test  : 962 | Perplexity :  818.28982 | Per doc ppx :  883.32338 | KLD :   27.97804
#
# Epoch train : 963 | Perplexity :  589.15499 | Per doc ppx :  685.43682 | KLD :   30.86029
# Epoch train : 963 | Perplexity :  588.69842 | Per doc ppx :  685.65034 | KLD :   30.81822
# Epoch test  : 963 | Perplexity :  817.52437 | Per doc ppx :  880.02016 | KLD :   28.07036
#
# Epoch train : 964 | Perplexity :  589.04777 | Per doc ppx :  685.29036 | KLD :   30.98478
# Epoch train : 964 | Perplexity :  588.81741 | Per doc ppx :  685.47579 | KLD :   30.81216
# Epoch test  : 964 | Perplexity :  817.43397 | Per doc ppx :  882.70533 | KLD :   27.84224
#
# Epoch train : 965 | Perplexity :  588.87292 | Per doc ppx :  685.07071 | KLD :   30.70629
# Epoch train : 965 | Perplexity :  589.11198 | Per doc ppx :  686.41290 | KLD :   30.77049
# Epoch test  : 965 | Perplexity :  816.44924 | Per doc ppx :  883.70981 | KLD :   27.93840
#
# Epoch train : 966 | Perplexity :  589.20203 | Per doc ppx :  686.16313 | KLD :   30.90560
# Epoch train : 966 | Perplexity :  589.41278 | Per doc ppx :  689.12622 | KLD :   30.91484
# Epoch test  : 966 | Perplexity :  819.02937 | Per doc ppx :  885.59003 | KLD :   27.87979
#
# Epoch train : 967 | Perplexity :  589.68230 | Per doc ppx :  686.34740 | KLD :   30.77372
# Epoch train : 967 | Perplexity :  589.33619 | Per doc ppx :  685.50620 | KLD :   30.84640
# Epoch test  : 967 | Perplexity :  814.99614 | Per doc ppx :  886.81580 | KLD :   28.16437
#
# Epoch train : 968 | Perplexity :  589.64321 | Per doc ppx :  686.85940 | KLD :   31.02520
# Epoch train : 968 | Perplexity :  589.13233 | Per doc ppx :  687.44736 | KLD :   30.85859
# Epoch test  : 968 | Perplexity :  817.10751 | Per doc ppx :  883.62450 | KLD :   28.05056
#
# Epoch train : 969 | Perplexity :  589.49852 | Per doc ppx :  686.47435 | KLD :   30.96645
# Epoch train : 969 | Perplexity :  589.39173 | Per doc ppx :  686.87450 | KLD :   30.88138
# Epoch test  : 969 | Perplexity :  816.93959 | Per doc ppx :  884.38804 | KLD :   27.85865
#
# Epoch train : 970 | Perplexity :  589.72958 | Per doc ppx :  688.61991 | KLD :   30.80614
# Epoch train : 970 | Perplexity :  588.82844 | Per doc ppx :  684.52386 | KLD :   30.85451
# Epoch test  : 970 | Perplexity :  818.89682 | Per doc ppx :  886.01529 | KLD :   27.93510
#
# Epoch train : 971 | Perplexity :  589.20960 | Per doc ppx :  687.06020 | KLD :   30.87827
# Epoch train : 971 | Perplexity :  589.72318 | Per doc ppx :  687.52681 | KLD :   30.90402
# Epoch test  : 971 | Perplexity :  819.33011 | Per doc ppx :  884.38928 | KLD :   27.94114
#
# Epoch train : 972 | Perplexity :  589.44739 | Per doc ppx :  686.25497 | KLD :   30.86730
# Epoch train : 972 | Perplexity :  589.65114 | Per doc ppx :  687.22552 | KLD :   30.91275
# Epoch test  : 972 | Perplexity :  819.11629 | Per doc ppx :  882.94853 | KLD :   28.00142
#
# Epoch train : 973 | Perplexity :  589.17091 | Per doc ppx :  685.23955 | KLD :   30.90099
# Epoch train : 973 | Perplexity :  588.81582 | Per doc ppx :  686.30426 | KLD :   30.85720
# Epoch test  : 973 | Perplexity :  816.71468 | Per doc ppx :  883.25127 | KLD :   27.95141
#
# Epoch train : 974 | Perplexity :  589.17942 | Per doc ppx :  685.98042 | KLD :   30.93895
# Epoch train : 974 | Perplexity :  588.84335 | Per doc ppx :  685.96206 | KLD :   30.89420
# Epoch test  : 974 | Perplexity :  818.04594 | Per doc ppx :  883.37240 | KLD :   27.90770
#
# Epoch train : 975 | Perplexity :  589.31535 | Per doc ppx :  685.30885 | KLD :   30.79773
# Epoch train : 975 | Perplexity :  589.09654 | Per doc ppx :  685.41983 | KLD :   30.84358
# Epoch test  : 975 | Perplexity :  817.40103 | Per doc ppx :  885.07268 | KLD :   28.21136
#
# Epoch train : 976 | Perplexity :  589.51503 | Per doc ppx :  688.35871 | KLD :   31.03232
# Epoch train : 976 | Perplexity :  589.63909 | Per doc ppx :  687.68756 | KLD :   30.84014
# Epoch test  : 976 | Perplexity :  817.80898 | Per doc ppx :  884.47714 | KLD :   27.98272
#
# Epoch train : 977 | Perplexity :  589.15433 | Per doc ppx :  687.15857 | KLD :   30.88335
# Epoch train : 977 | Perplexity :  589.30965 | Per doc ppx :  687.59248 | KLD :   30.88658
# Epoch test  : 977 | Perplexity :  819.06570 | Per doc ppx :  889.82791 | KLD :   28.09811
#
# Epoch train : 978 | Perplexity :  589.10645 | Per doc ppx :  687.24935 | KLD :   30.95601
# Epoch train : 978 | Perplexity :  589.06649 | Per doc ppx :  686.83289 | KLD :   30.83453
# Epoch test  : 978 | Perplexity :  817.29976 | Per doc ppx :  887.30848 | KLD :   27.90865
#
# Epoch train : 979 | Perplexity :  589.25162 | Per doc ppx :  687.21783 | KLD :   30.74104
# Epoch train : 979 | Perplexity :  589.28399 | Per doc ppx :  686.23094 | KLD :   30.83792
# Epoch test  : 979 | Perplexity :  818.66434 | Per doc ppx :  887.11409 | KLD :   27.95539
#
# Epoch train : 980 | Perplexity :  589.00424 | Per doc ppx :  684.87224 | KLD :   30.89340
# Epoch train : 980 | Perplexity :  589.15025 | Per doc ppx :  685.02915 | KLD :   30.91906
# Epoch test  : 980 | Perplexity :  816.53719 | Per doc ppx :  883.99577 | KLD :   27.99912
#
# Epoch train : 981 | Perplexity :  588.56540 | Per doc ppx :  684.97385 | KLD :   30.95126
# Epoch train : 981 | Perplexity :  589.01675 | Per doc ppx :  685.29789 | KLD :   30.89080
# Epoch test  : 981 | Perplexity :  820.26922 | Per doc ppx :  887.30062 | KLD :   27.91514
#
# Epoch train : 982 | Perplexity :  589.64379 | Per doc ppx :  686.55832 | KLD :   30.76032
# Epoch train : 982 | Perplexity :  589.34238 | Per doc ppx :  687.83578 | KLD :   30.83455
# Epoch test  : 982 | Perplexity :  817.30840 | Per doc ppx :  882.59201 | KLD :   28.09903
#
# Epoch train : 983 | Perplexity :  588.88223 | Per doc ppx :  685.06268 | KLD :   30.94040
# Epoch train : 983 | Perplexity :  588.79051 | Per doc ppx :  686.11065 | KLD :   30.75899
# Epoch test  : 983 | Perplexity :  818.68135 | Per doc ppx :  885.03399 | KLD :   27.95960
#
# Epoch train : 984 | Perplexity :  588.87344 | Per doc ppx :  685.77639 | KLD :   30.87135
# Epoch train : 984 | Perplexity :  589.26475 | Per doc ppx :  686.89909 | KLD :   30.91979
# Epoch test  : 984 | Perplexity :  816.97948 | Per doc ppx :  882.48674 | KLD :   28.01729
#
# Epoch train : 985 | Perplexity :  589.06727 | Per doc ppx :  685.88464 | KLD :   30.85576
# Epoch train : 985 | Perplexity :  589.04975 | Per doc ppx :  686.90085 | KLD :   30.84458
# Epoch test  : 985 | Perplexity :  818.01761 | Per doc ppx :  884.44044 | KLD :   27.93467
#
# Epoch train : 986 | Perplexity :  589.07098 | Per doc ppx :  685.13212 | KLD :   30.79154
# Epoch train : 986 | Perplexity :  589.22840 | Per doc ppx :  687.70954 | KLD :   30.85733
# Epoch test  : 986 | Perplexity :  821.30056 | Per doc ppx :  885.36495 | KLD :   28.05110
#
# Epoch train : 987 | Perplexity :  589.34934 | Per doc ppx :  685.47171 | KLD :   30.87956
# Epoch train : 987 | Perplexity :  589.47461 | Per doc ppx :  686.50896 | KLD :   30.85355
# Epoch test  : 987 | Perplexity :  819.55996 | Per doc ppx :  886.26157 | KLD :   28.13435
#
# Epoch train : 988 | Perplexity :  589.44557 | Per doc ppx :  685.63284 | KLD :   31.06627
# Epoch train : 988 | Perplexity :  589.36519 | Per doc ppx :  688.15665 | KLD :   30.95233
# Epoch test  : 988 | Perplexity :  818.19561 | Per doc ppx :  885.88458 | KLD :   28.10824
#
# Epoch train : 989 | Perplexity :  589.70496 | Per doc ppx :  687.50028 | KLD :   31.01031
# Epoch train : 989 | Perplexity :  588.84658 | Per doc ppx :  686.42286 | KLD :   30.85244
# Epoch test  : 989 | Perplexity :  819.82200 | Per doc ppx :  884.45928 | KLD :   27.85526
#
# Epoch train : 990 | Perplexity :  589.13655 | Per doc ppx :  687.35175 | KLD :   30.75484
# Epoch train : 990 | Perplexity :  588.94408 | Per doc ppx :  685.41789 | KLD :   30.83638
# Epoch test  : 990 | Perplexity :  817.17749 | Per doc ppx :  884.07267 | KLD :   27.78790
#
# Epoch train : 991 | Perplexity :  589.58441 | Per doc ppx :  687.28085 | KLD :   30.69217
# Epoch train : 991 | Perplexity :  589.29691 | Per doc ppx :  684.54430 | KLD :   30.85383
# Epoch test  : 991 | Perplexity :  816.39028 | Per doc ppx :  880.86595 | KLD :   28.07838
#
# Epoch train : 992 | Perplexity :  589.20456 | Per doc ppx :  687.05715 | KLD :   30.97250
# Epoch train : 992 | Perplexity :  589.33301 | Per doc ppx :  687.03737 | KLD :   30.92959
# Epoch test  : 992 | Perplexity :  817.72190 | Per doc ppx :  880.92177 | KLD :   27.96341
#
# Epoch train : 993 | Perplexity :  589.50080 | Per doc ppx :  687.84977 | KLD :   30.89173
# Epoch train : 993 | Perplexity :  589.34128 | Per doc ppx :  687.00847 | KLD :   30.91530
# Epoch test  : 993 | Perplexity :  816.13247 | Per doc ppx :  880.18059 | KLD :   28.08635
#
# Epoch train : 994 | Perplexity :  588.99173 | Per doc ppx :  684.86707 | KLD :   30.98689
# Epoch train : 994 | Perplexity :  589.46638 | Per doc ppx :  685.83838 | KLD :   30.89561
# Epoch test  : 994 | Perplexity :  817.83132 | Per doc ppx :  882.60382 | KLD :   27.96023
#
# Epoch train : 995 | Perplexity :  589.13362 | Per doc ppx :  687.46837 | KLD :   30.80581
# Epoch train : 995 | Perplexity :  588.84819 | Per doc ppx :  684.61682 | KLD :   30.80989
# Epoch test  : 995 | Perplexity :  817.08033 | Per doc ppx :  884.94828 | KLD :   27.90124
#
# Epoch train : 996 | Perplexity :  589.43636 | Per doc ppx :  688.06263 | KLD :   30.76297
# Epoch train : 996 | Perplexity :  588.81452 | Per doc ppx :  686.42873 | KLD :   30.77775
# Epoch test  : 996 | Perplexity :  820.53802 | Per doc ppx :  882.88293 | KLD :   27.86927
#
# Epoch train : 997 | Perplexity :  589.24457 | Per doc ppx :  686.93898 | KLD :   30.81969
# Epoch train : 997 | Perplexity :  589.33272 | Per doc ppx :  687.12498 | KLD :   30.90135
# Epoch test  : 997 | Perplexity :  819.54313 | Per doc ppx :  883.96639 | KLD :   28.06183
#
# Epoch train : 998 | Perplexity :  588.57116 | Per doc ppx :  684.99377 | KLD :   30.92941
# Epoch train : 998 | Perplexity :  588.72633 | Per doc ppx :  686.44875 | KLD :   30.81869
# Epoch test  : 998 | Perplexity :  818.30050 | Per doc ppx :  882.81692 | KLD :   27.84621
#
# Epoch train : 999 | Perplexity :  588.77317 | Per doc ppx :  685.35602 | KLD :   30.71675
# Epoch train : 999 | Perplexity :  588.57533 | Per doc ppx :  684.67268 | KLD :   30.80245
# Epoch test  : 999 | Perplexity :  817.60532 | Per doc ppx :  885.13965 | KLD :   27.81605
#
# Epoch train : 1000 | Perplexity :  589.32658 | Per doc ppx :  686.11293 | KLD :   30.77350
# Epoch train : 1000 | Perplexity :  588.80744 | Per doc ppx :  685.54102 | KLD :   30.89978
# Epoch test  : 1000 | Perplexity :  819.72181 | Per doc ppx :  888.57163 | KLD :   27.80895

# %%
record() #top 10
# Out:
# Topic  1 :  netcom, proposal, braves, ball, pgp, cops, ripem, escrow, solar, austin
# Topic  2 :  environment, umd, differences, minority, east, mph, guide, men, alan, higher
# Topic  3 :  georgia, johnson, db, secretary, equipment, music, battery, volume, education, select
# Topic  4 :  tax, rates, taxes, congress, bnr, printf, okay, col, authority, bmw
# Topic  5 :  chi, iastate, van, church, andy, released, militia, ex, meeting, cal
# Topic  6 :  pro, germany, german, gun, muslim, muslims, genocide, isc, armenians, select
# Topic  7 :  like, just, out, know, don, who, how, only, which, up
# Topic  8 :  pages, expansion, sets, brian, east, postscript, party, criminal, moon, described
# Topic  9 :  rom, cd, animals, product, march, archive, att, products, gm, compression
# Topic 10 :  door, her, she, apartment, search, announced, coverage, package, austin, zip
# Topic 11 :  gm, stratus, button, xt, congress, em, art, microsoft, business, father
# Topic 12 :  entries, russian, gif, objects, document, fonts, zip, author, file, font
# Topic 13 :  white, black, motif, recommend, colors, color, background, sgi, traffic, jose
# Topic 14 :  mon, riding, csd, resolution, spot, peace, zone, meeting, israel, israeli
# Topic 15 :  crypto, serial, nsa, secret, eff, escrow, cryptography, rsa, encryption, agencies
# Topic 16 :  encryption, encrypted, caltech, cryptography, clipper, rsa, pgp, enforcement, crime, criminal
# Topic 17 :  dog, motorcycle, directory, morning, bike, ride, hole, dod, wire, mary
# Topic 18 :  henry, colorado, firearms, seattle, gun, toronto, weapon, los, guns, king
# Topic 19 :  panel, caltech, moral, killing, kids, penalty, acts, cops, sunday, font
# Topic 20 :  austin, everybody, levels, resolution, utexas, si, iastate, fonts, mcgill, blood
# Topic 21 :  fuel, oil, surface, risk, aids, water, test, advice, draft, cancer
# Topic 22 :  trial, gordon, bytes, banks, cache, pitt, civilians, azerbaijan, keyboard, women
# Topic 23 :  mot, chi, min, roger, percent, father, character, corp, mass, rob
# Topic 24 :  weapon, justice, land, peace, root, tim, villages, militia, position, fonts
# Topic 25 :  navy, secretary, ti, animals, creation, medical, environment, create, created, sick
# Topic 26 :  oil, california, moving, announced, radar, francisco, room, release, action, gas
# Topic 27 :  weak, disks, default, bytes, processor, encrypted, double, perfect, versions, bits
# Topic 28 :  output, compression, unit, input, low, remote, panel, hardware, operations, program
# Topic 29 :  pts, mon, xlib, shots, player, xterm, min, philadelphia, stats, conference
# Topic 30 :  resource, saturn, col, pain, command, discuss, penalty, ice, tool, hours
# Topic 31 :  aids, drug, cb, brain, ide, drugs, cancer, bbs, columbia, rates
# Topic 32 :  answers, stats, angeles, jobs, face, frequently, possibility, ron, committee, los
# Topic 33 :  navy, jpl, nasa, disease, surface, types, gov, pt, dangerous, green
# Topic 34 :  bc, freenet, wings, leafs, civilians, msg, ca, kill, animals, anti
# Topic 35 :  mailing, mass, committee, lock, contrib, list, auto, rec, radar, jason
# Topic 36 :  isc, douglas, br, pts, battery, weight, functions, boston, solid, utexas
# Topic 37 :  bike, sale, dod, shipping, car, bmw, rec, insurance, sold, selling
# Topic 38 :  nuclear, energy, troops, max, base, lunar, vga, border, cold, sea
# Topic 39 :  creation, master, format, governments, un, mil, acts, secure, begin, president
# Topic 40 :  harvard, ohio, acs, budget, udel, amendment, lock, navy, mi, manual
# Topic 41 :  playoffs, hockey, teams, nhl, leafs, players, baseball, fans, team, season
# Topic 42 :  music, nuclear, ryan, jon, oil, max, tech, se, po, germany
# Topic 43 :  zip, anonymous, errors, postings, automatic, magazine, utexas, service, attitude, turbo
# Topic 44 :  jack, brad, border, lebanese, noise, path, tape, caught, stars, organization
# Topic 45 :  defense, forces, military, armed, shots, shot, police, civilians, weapon, enforcement
# Topic 46 :  orbit, saturn, satellite, lunar, launch, shuttle, science, solar, moon, space
# Topic 47 :  colors, entries, export, white, immediately, keyboard, edge, products, umd, feet
# Topic 48 :  pts, simms, att, cb, pat, bits, universe, null, ns, reported
# Topic 49 :  cso, uiuc, fonts, udel, jpl, compound, iastate, lib, worked, blame
# Topic 50 :  german, audio, vancouver, detroit, udel, russian, objects, option, montreal, electrical
