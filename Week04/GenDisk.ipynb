# %%
import scipy.io as sio
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from scipy.stats import multivariate_normal

# %matplotlib inline

# %%
x1 = np.arange(0,4,0.1)
x2 = np.arange(-.5,3,.1)

# %%
[X1, X2] = np.meshgrid(x1,x2)
X1 = X1.reshape(np.size(X1),1);
X2 = X2.reshape(np.size(X2),1);

# %%
mu = np.array([1,1]);
Sigma = np.array([.1, 0, 0, .3]).reshape(2,2)
X = np.column_stack((X1, X2));
F = multivariate_normal.pdf(X, mu,Sigma)
F = F.reshape(np.size(x2), np.size(x1))

# %%
mu2 = np.array([2.5,1]);
Sigma2 = np.array([.3, 0, 0, .1]).reshape(2,2)
X = np.column_stack((X1, X2));
F2 = multivariate_normal.pdf(X, mu2,Sigma2)
F2 = F2.reshape(np.size(x2), np.size(x1))

# %%
fig = plt.figure(1, figsize = (15,10));
ax = fig.add_subplot(2, 2, 1,projection='3d')

[X1, X2] = np.meshgrid(x1,x2)
surf = ax.plot_surface(X1, X2, F, rstride=1, cstride=1, cmap=cm.coolwarm,linewidth=0, antialiased=True)


ax = fig.add_subplot(2, 2, 2,projection='3d')
surf2 = ax.plot_surface(X1, X2, F2, rstride=1, cstride=1, cmap=cm.coolwarm,linewidth=0, antialiased=True)

ax = fig.add_subplot(2, 2, 3,projection='3d')
surf = ax.plot_surface(X1, X2, F, rstride=1, cstride=1, cmap=cm.coolwarm,linewidth=0, antialiased=True)
surf2 = ax.plot_surface(X1, X2, F2, rstride=1, cstride=1, cmap=cm.coolwarm,linewidth=0, antialiased=True)
plt.show()

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# %%
np.size(X1)
# Out:
# 1400
